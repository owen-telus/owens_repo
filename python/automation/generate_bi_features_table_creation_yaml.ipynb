# %%
import pandas as pd
import numpy as np

# %%
# %%bigquery df
#
# SELECT
#   A.* ,
#   B.description
# FROM `featurehub-pr-9964dc.msisdn_data_usage.INFORMATION_SCHEMA.COLUMNS` A
# LEFT JOIN `featurehub-pr-9964dc.msisdn_data_usage.INFORMATION_SCHEMA.COLUMN_FIELD_PATHS` B
# ON A.column_name = B.column_name
# WHERE A.table_name = 'bq_msisdn_data_usage_l3m' AND B.table_name = 'bq_msisdn_data_usage_l3m'
# Out:
# Query complete after 0.04s: 100% 3/3 [00:00<00:00, 1581.36query/s]
# Downloading: 100% 28/28 [00:00<00:00, 41.07rows/s]

# %%
df.head()
# Out:
#           table_catalog       table_schema                table_name  \
# 0  featurehub-pr-9964dc  msisdn_data_usage  bq_msisdn_data_usage_l3m
# 1  featurehub-pr-9964dc  msisdn_data_usage  bq_msisdn_data_usage_l3m
# 2  featurehub-pr-9964dc  msisdn_data_usage  bq_msisdn_data_usage_l3m
# 3  featurehub-pr-9964dc  msisdn_data_usage  bq_msisdn_data_usage_l3m
# 4  featurehub-pr-9964dc  msisdn_data_usage  bq_msisdn_data_usage_l3m
#
#             column_name  ordinal_position is_nullable data_type is_generated  \
# 0               part_dt                 1         YES      DATE        NEVER
# 1               mob_ban                 2         YES   NUMERIC        NEVER
# 2                msisdn                 3         YES   NUMERIC        NEVER
# 3  bill_cycle_clos_dt_1                 4         YES      DATE        NEVER
# 4  bill_cycle_clos_dt_2                 5         YES      DATE        NEVER
#
#   generation_expression is_stored is_hidden is_updatable is_system_defined  \
# ...

# %%
for index, row in df.iterrows():
    print('{"name": "' + row['column_name'] + '", \t "type": "' + row['data_type'] + '", \t  "mode": "NULLABLE", \t "description": "' + row['description'] + '"},' )
# Out:
# {"name": "part_dt", 	 "type": "DATE", 	  "mode": "NULLABLE", 	 "description": "Partition Date"},
# {"name": "mob_ban", 	 "type": "NUMERIC", 	  "mode": "NULLABLE", 	 "description": "MOBILITY BAN"},
# {"name": "msisdn", 	 "type": "NUMERIC", 	  "mode": "NULLABLE", 	 "description": "msisdn"},
# {"name": "bill_cycle_clos_dt_1", 	 "type": "DATE", 	  "mode": "NULLABLE", 	 "description": "Bill Cycle Close Date - Current Month"},
# {"name": "bill_cycle_clos_dt_2", 	 "type": "DATE", 	  "mode": "NULLABLE", 	 "description": "Bill Cycle Close Date - 1 month ago"},
# {"name": "bill_cycle_clos_dt_3", 	 "type": "DATE", 	  "mode": "NULLABLE", 	 "description": "Bill Cycle Close Date - 2 months ago"},
# {"name": "num_days_data_throttled_1", 	 "type": "NUMERIC", 	  "mode": "NULLABLE", 	 "description": "Number of Days data was throttled in billing cycle - Current Month"},
# ...
